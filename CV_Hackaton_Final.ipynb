# %% [markdown]
# # Requirements

# %%
# !pip install fiftyone
# !pip install roboflow
import fiftyone as fo
from roboflow import Roboflow
# Out:
# Collecting fiftyone
#   Downloading fiftyone-1.3.2-py3-none-any.whl.metadata (24 kB)
# Collecting aiofiles (from fiftyone)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting argcomplete (from fiftyone)
#   Downloading argcomplete-3.6.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.13.3)
# Collecting boto3 (from fiftyone)
#   Downloading boto3-1.37.13-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from fiftyone) (5.5.2)
# Collecting dacite<1.8.0,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.7.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from fiftyone) (1.2.18)
# Collecting ftfy (from fiftyone)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.11.0)
# Collecting hypercorn>=0.13.2 (from fiftyone)
#   Downloading hypercorn-0.17.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: Jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (3.1.6)
# Collecting kaleido!=0.2.1.post1 (from fiftyone)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from fiftyone) (3.10.0)
# Collecting mongoengine~=0.29.1 (from fiftyone)
#   Downloading mongoengine-0.29.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting motor~=3.6.0 (from fiftyone)
#   Downloading motor-3.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fiftyone) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fiftyone) (24.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2.2.2)
# Requirement already satisfied: Pillow>=6.2 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (11.1.0)
# Requirement already satisfied: plotly>=4.14 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (5.24.1)
# Collecting pprintpp (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from fiftyone) (5.9.5)
# Collecting pymongo~=4.9.2 (from fiftyone)
#   Downloading pymongo-4.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2025.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from fiftyone) (6.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2024.11.6)
# Collecting retrying (from fiftyone)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting rtree (from fiftyone)
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from fiftyone) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from fiftyone) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from fiftyone) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from fiftyone) (75.1.0)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting sse-starlette<1,>=0.10.3 (from fiftyone)
#   Downloading sse_starlette-0.10.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting starlette>=0.24.0 (from fiftyone)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting strawberry-graphql (from fiftyone)
#   Downloading strawberry_graphql-0.262.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from fiftyone) (0.9.0)
# Collecting xmltodict (from fiftyone)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting pydash (from fiftyone)
#   Downloading pydash-8.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting fiftyone-brain<0.20,>=0.19.0 (from fiftyone)
#   Downloading fiftyone_brain-0.19.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting fiftyone-db<2.0,>=0.4 (from fiftyone)
#   Downloading fiftyone_db-1.1.7.tar.gz (7.9 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting voxel51-eta<0.15,>=0.14.0 (from fiftyone)
#   Downloading voxel51_eta-0.14.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.11.0.86)
# Requirement already satisfied: h11 in /usr/local/lib/python3.11/dist-packages (from hypercorn>=0.13.2->fiftyone) (0.14.0)
# Requirement already satisfied: h2>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from hypercorn>=0.13.2->fiftyone) (4.2.0)
# Collecting priority (from hypercorn>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wsproto>=0.14.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3->fiftyone) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.14->fiftyone) (9.0.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.9.2->fiftyone)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette>=0.24.0->fiftyone) (3.7.1)
# Requirement already satisfied: httpx>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Collecting dill (from voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (1.0.0)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting py7zr (from voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading py7zr-0.22.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.8.2)
# Collecting rarfile (from voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (1.17.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (5.3.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->fiftyone) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->fiftyone) (4.12.2)
# Collecting botocore<1.38.0,>=1.37.13 (from boto3->fiftyone)
#   Downloading botocore-1.37.13-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->fiftyone)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3->fiftyone)
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->fiftyone) (1.17.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->fiftyone) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (3.2.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fiftyone) (2025.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (2025.2.18)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->fiftyone) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->fiftyone) (3.5.0)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql->fiftyone)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (1.3.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines->voxel51-eta<0.15,>=0.14.0->fiftyone) (25.2.0)
# Collecting texttable (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting pyzstd>=0.15.9 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading pyzstd-0.16.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading pyppmd-1.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading pybcj-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading inflate64-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting brotli>=1.1.0 (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone)
#   Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->voxel51-eta<0.15,>=0.14.0->fiftyone) (3.4.1)
# Downloading fiftyone-1.3.2-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 59.9 MB/s eta 0:00:00
# Downloading dacite-1.7.0-py3-none-any.whl (12 kB)
# Downloading fiftyone_brain-0.19.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 6.8 MB/s eta 0:00:00
# Downloading hypercorn-0.17.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.0 MB/s eta 0:00:00
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.3 MB/s eta 0:00:00
# Downloading mongoengine-0.29.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 7.3 MB/s eta 0:00:00
# Downloading motor-3.6.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 5.6 MB/s eta 0:00:00
# Downloading pymongo-4.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.6 MB/s eta 0:00:00
# Downloading sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.2 MB/s eta 0:00:00
# Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Downloading voxel51_eta-0.14.0-py2.py3-none-any.whl (942 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 943.0/943.0 kB 40.5 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading argcomplete-3.6.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.0 MB/s eta 0:00:00
# Downloading boto3-1.37.13-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 9.0 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pydash-8.0.5-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.1/102.1 kB 7.6 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 32.6 MB/s eta 0:00:00
# Downloading strawberry_graphql-0.262.5-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.0/296.0 kB 17.2 MB/s eta 0:00:00
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Downloading botocore-1.37.13-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 88.5 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.8 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 15.1 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 6.3 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 7.9 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Downloading py7zr-0.22.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 4.8 MB/s eta 0:00:00
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 67.6 MB/s eta 0:00:00
# Downloading inflate64-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 6.7 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.6 MB/s eta 0:00:00
# Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 56.7 MB/s eta 0:00:00
# Downloading pyppmd-1.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 9.4 MB/s eta 0:00:00
# Downloading pyzstd-0.16.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.7/413.7 kB 24.5 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fiftyone-db
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.1.7-py3-none-manylinux1_x86_64.whl size=42156214 sha256=5213a882dda8bd5f3c4bd97dcbe379418b49e610a0d32bbaf7bc7f7852b9125e
#   Stored in directory: /root/.cache/pip/wheels/bf/75/da/54cd52c92db9f0c4e88ca5efdbac2304b49927249c9c859b8d
# Successfully built fiftyone-db
# Installing collected packages: texttable, sseclient-py, pprintpp, kaleido, brotli, xmltodict, wsproto, rtree, retrying, rarfile, pyzstd, pyppmd, pydash, pycryptodomex, pybcj, priority, multivolumefile, jsonlines, jmespath, inflate64, graphql-core, ftfy, fiftyone-db, dnspython, dill, dacite, argcomplete, aiofiles, strawberry-graphql, starlette, pymongo, py7zr, hypercorn, botocore, voxel51-eta, universal-analytics-python3, sse-starlette, s3transfer, motor, mongoengine, fiftyone-brain, boto3, fiftyone
# Successfully installed aiofiles-24.1.0 argcomplete-3.6.0 boto3-1.37.13 botocore-1.37.13 brotli-1.1.0 dacite-1.7.0 dill-0.3.9 dnspython-2.7.0 fiftyone-1.3.2 fiftyone-brain-0.19.0 fiftyone-db-1.1.7 ftfy-6.3.1 graphql-core-3.2.6 hypercorn-0.17.3 inflate64-1.0.1 jmespath-1.0.1 jsonlines-4.0.0 kaleido-0.2.1 mongoengine-0.29.1 motor-3.6.1 multivolumefile-0.2.3 pprintpp-0.4.0 priority-2.0.0 py7zr-0.22.0 pybcj-1.0.3 pycryptodomex-3.21.0 pydash-8.0.5 pymongo-4.9.2 pyppmd-1.1.1 pyzstd-0.16.2 rarfile-4.2 retrying-1.3.4 rtree-1.4.0 s3transfer-0.11.4 sse-starlette-0.10.3 sseclient-py-1.8.0 starlette-0.46.1 strawberry-graphql-0.262.5 texttable-1.7.0 universal-analytics-python3-1.1.1 voxel51-eta-0.14.0 wsproto-1.2.0 xmltodict-0.14.2
# Collecting roboflow
#   Downloading roboflow-1.1.58-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.1.0)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.1.58-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.6 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.4 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.6 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.0.1 roboflow-1.1.58

# %% [markdown]
# # Import & Load the Data

# %%
rf = Roboflow(api_key="NpeBlgiGKRnkLj4kIL2C")
project = rf.workspace("safewalkbd").project("safewalkbd-l8jbn")
version = project.version(9)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import os
import shutil

dataset_dir = "/content/SafeWalkBD-9"

for split in ["train", "valid", "test"]:
    split_path = os.path.join(dataset_dir, split)
    data_path = os.path.join(split_path, "data")

    # Create 'data' folder if it doesn't exist
    if not os.path.exists(data_path):
        os.makedirs(data_path)

    # Move all image files into 'data/' subfolder
    for file in os.listdir(split_path):
        if file.endswith(".jpg") or file.endswith(".png"):  # Adjust for other image formats if needed
            shutil.move(os.path.join(split_path, file), os.path.join(data_path, file))

print("Folder structure updated successfully.")
# Out:
# Folder structure updated successfully.

# %%
# Load the training dataset
train_dataset = fo.Dataset.from_dir(
    dataset_dir=f"{dataset_dir}/train",
    dataset_type=fo.types.COCODetectionDataset,
    labels_path=f"{dataset_dir}/train/_annotations.coco.json"
)

# Load the validation dataset
valid_dataset = fo.Dataset.from_dir(
    dataset_dir=f"{dataset_dir}/valid",
    dataset_type=fo.types.COCODetectionDataset,
    labels_path=f"{dataset_dir}/valid/_annotations.coco.json"
)

# Load the test dataset
test_dataset = fo.Dataset.from_dir(
    dataset_dir=f"{dataset_dir}/test",
    dataset_type=fo.types.COCODetectionDataset,
    labels_path=f"{dataset_dir}/test/_annotations.coco.json"
)
# Out:
#  100% |███████████████| 7193/7193 [58.8s elapsed, 0s remaining, 115.8 samples/s]
# INFO:eta.core.utils: 100% |███████████████| 7193/7193 [58.8s elapsed, 0s remaining, 115.8 samples/s]
#  100% |███████████████| 1989/1989 [14.8s elapsed, 0s remaining, 162.5 samples/s]
# INFO:eta.core.utils: 100% |███████████████| 1989/1989 [14.8s elapsed, 0s remaining, 162.5 samples/s]
#   92% |█████████████\-|  973/1059 [9.3s elapsed, 840.7ms remaining, 102.1 samples/s]

# %%
# Launch FiftyOne app for visualization
session = fo.launch_app(train_dataset)

# %% [markdown]
# # Text cleaning for irreleveant images

# %%
import cv2
import numpy as np
import os
from PIL import Image
import shutil

def is_street_view(image_path, road_threshold=0.2, sidewalk_threshold=0.1):
    """
    Checks if an image is a street view based on the presence of roads and sidewalks.

    Args:
        image_path (str): Path to the image file.
        road_threshold (float): Minimum proportion of road pixels to consider it a street view.
        sidewalk_threshold (float): Minimum proportion of sidewalk pixels to consider it a street view.

    Returns:
        bool: True if it's a street view, False otherwise.
    """

    try:
        img = cv2.imread(image_path)
        if img is None:
            return False
        img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

        lower_road = np.array([0, 0, 0])
        upper_road = np.array([180, 50, 100])

        lower_sidewalk = np.array([0, 0, 50])
        upper_sidewalk = np.array([180, 30, 200])

        road_mask = cv2.inRange(img_hsv, lower_road, upper_road)
        sidewalk_mask = cv2.inRange(img_hsv, lower_sidewalk, upper_sidewalk)

        road_pixels = np.count_nonzero(road_mask)
        sidewalk_pixels = np.count_nonzero(sidewalk_mask)
        total_pixels = img.shape[0] * img.shape[1]

        road_proportion = road_pixels / total_pixels
        sidewalk_proportion = sidewalk_pixels / total_pixels

        return road_proportion > road_threshold or sidewalk_proportion > sidewalk_threshold

    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return False

def filter_street_view_dataset(input_root_dir, output_root_dir):
    """
    Filters street view images within a dataset structure (train, test, valid).

    Args:
        input_root_dir (str): Root directory containing train, test, valid subdirectories.
        output_root_dir (str): Root directory to store filtered street view images.
    """

    for subdir in ["train/data", "test/data", "valid/data"]:
        input_subdir = os.path.join(input_root_dir, subdir)
        output_subdir = os.path.join(output_root_dir, subdir)

        if not os.path.exists(input_subdir):
            print(f"Warning: Subdirectory '{input_subdir}' not found.")
            continue

        if not os.path.exists(output_subdir):
            os.makedirs(output_subdir)

        for filename in os.listdir(input_subdir):
            if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                image_path = os.path.join(input_subdir, filename)
                if is_street_view(image_path):
                    output_path = os.path.join(output_subdir, filename)
                    try:
                        Image.open(image_path).save(output_path)
                        print(f"Copied {filename} from {subdir} to {output_subdir}")
                    except Exception as e:
                        print(f"Error copying {filename}: {e}")
def clean_non_street_view(input_root_dir):
    """
    Deletes non-street view images from the input directories.
    """
    for subdir in ["train/data", "test/data", "valid/data"]:
        input_subdir = os.path.join(input_root_dir, subdir)

        if not os.path.exists(input_subdir):
            print(f"Warning: Subdirectory '{input_subdir}' not found.")
            continue

        for filename in os.listdir(input_subdir):
            if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                image_path = os.path.join(input_subdir, filename)
                if not is_street_view(image_path):
                    try:
                        os.remove(image_path)
                        print(f"Deleted {filename} from {subdir}")
                    except Exception as e:
                        print(f"Error deleting {filename}: {e}")

# %%
# Example usage:
input_root_directory = dataset_dir  # Replace with your input root directory
output_root_directory = "/content/filtered_dataset/" #Replace with your desired output directory.

#Copy the street view images to a new location.
filter_street_view_dataset(input_root_directory, output_root_directory)

#Or, delete the non street view images from the existing directory.
#clean_non_street_view(input_root_directory)
# Out:
# Copied 336_png_jpg.rf.3ec2792295d97be37e1b489285808bfc.jpg from train to /content/filtered_dataset/train
# Copied images180_jpg.rf.df158d2ae784d3eb3bb603690f8da689.jpg from train to /content/filtered_dataset/train
# Copied 461_png_jpg.rf.3e4e58e34144c7c3c238fb78f4cde012.jpg from train to /content/filtered_dataset/train
# Copied a2_156_jpg.rf.2663a49db1a3888000cb4e4c9ebdbbac.jpg from train to /content/filtered_dataset/train
# Copied T111076_jpg.rf.9d567bc819ae9b97df18f4c317feecca.jpg from train to /content/filtered_dataset/train
# Copied 533_png_jpg.rf.7c01b63feb647c58382981f5b848706d.jpg from train to /content/filtered_dataset/train
# Copied Autorickshaw-1-_jpg.rf.f16001a595fcd8b27b0150936495e0de.jpg from train to /content/filtered_dataset/train
# Copied T112435_jpg.rf.64ffd0ac7423385bdde31e535520ce7e.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_129_jpg.rf.9065cd17f4b8fed118bb8f5b58a6eec9.jpg from train to /content/filtered_dataset/train
# Copied curve-to-the-left46_jpg.rf.707f99b3fe572726966823dca6fd620e.jpg from train to /content/filtered_dataset/train
# Copied 371_png_jpg.rf.49f87a69276ce96a4f3633849d32c580.jpg from train to /content/filtered_dataset/train
# Copied 531_png_jpg.rf.7fed89d678c13d006f7f0445c6def467.jpg from train to /content/filtered_dataset/train
# Copied resized_frame_138_jpg.rf.e7d83592ce9c63ee0b55c2e72b905c03.jpg from train to /content/filtered_dataset/train
# Copied 634_jpg.rf.3d349a1a4653925f9c4ba13e0c1dd923.jpg from train to /content/filtered_dataset/train
# Copied Screenshot-from-2022-07-25-11-45-40_png_jpg.rf.d524fc6b221461918675f38a4b3a2ef6.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-20-_jpg.rf.e2fc3fbfa6067024e1f433a6cdc0279f.jpg from train to /content/filtered_dataset/train
# Copied 104_jpg.rf.01494236e50108bc5030caba8350c7c3.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-218-_jpg.rf.0f4b56ca46b8c9bc1dbbbfb7084d742a.jpg from train to /content/filtered_dataset/train
# Copied 407_png_jpg.rf.a985e5ce4539ab80b6a2ccb62ec645bc.jpg from train to /content/filtered_dataset/train
# Copied 1723730713557_jpg.rf.7ba8f21e9c6ca463ecf3727596341b44.jpg from train to /content/filtered_dataset/train
# Copied curve-to-the-left4_jpg.rf.ad12e0a7766d8fead1a996807d0b2aa1.jpg from train to /content/filtered_dataset/train
# Copied bus-110-_jpg.rf.0177996e18dfad7673b16dc70c1ad271.jpg from train to /content/filtered_dataset/train
# Copied 268_png_jpg.rf.53af74b8664a7d44b18585e6fcb8eb0f.jpg from train to /content/filtered_dataset/train
# Copied 000043_jpg.rf.0553b0f4e144eb184c6869c0a7830a35.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_320_jpg.rf.fa7543a7002c1075fd58e786da60f9fd.jpg from train to /content/filtered_dataset/train
# Copied 70_jpg.rf.a7ff49c94722d77f37de59da272a843d.jpg from train to /content/filtered_dataset/train
# Copied 1457_jpg.rf.c7d5775d7029e9fc088004310d4ffa94.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-66-_jpg.rf.f9f19391f054290b5ea628652609b79b.jpg from train to /content/filtered_dataset/train
# Copied images116_jpg.rf.a7f8c063bac6645d1c2370c5e4b4ba2f.jpg from train to /content/filtered_dataset/train
# Copied 017_png_jpg.rf.c00e86e8c6982a132b719b92f79f97ab.jpg from train to /content/filtered_dataset/train
# Copied T111154_jpg.rf.be42b14570ed9138ad1c2c1c6f506860.jpg from train to /content/filtered_dataset/train
# Copied crossroad-with-side-road-on-the-right38_jpg.rf.05f172f08ea483b2f6518cf59131049c.jpg from train to /content/filtered_dataset/train
# Copied 4964605321_output_jpg.rf.a01855502d6672cbd2b3bd78d8052052.jpg from train to /content/filtered_dataset/train
# Copied 4a358446-Screenshot_2024-02-06_at_17-04-20_png.rf.c004aa4e8e2ab63b2286b875ecc28084.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_50_jpg.rf.8dc81bf98e61631d95aef13efaafcbd4.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-182-_jpg.rf.2314e47519f285ff6811a69615b190eb.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-71-_jpg.rf.f30dcf91862ce4b1ca9d33bbb9448c8d.jpg from train to /content/filtered_dataset/train
# Copied 028_png_jpg.rf.45ffbf332377edddc2a043bb04868e22.jpg from train to /content/filtered_dataset/train
# Copied T112248_jpg.rf.14ff185d02f6fff0e7e800a2eb4668c2.jpg from train to /content/filtered_dataset/train
# Copied 227_jpg.rf.65e99141dae118332a3e87bcba026a22.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_296_jpg.rf.ca630abed043f1e08cfff82f6d1e0b54.jpg from train to /content/filtered_dataset/train
# Copied T111192_jpg.rf.7435181dcb43854e91f0a9434d24ab39.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_81_jpg.rf.3a1cde6ceb4923b7007caa5f74222030.jpg from train to /content/filtered_dataset/train
# Copied 00037_04_jpg.rf.d7a93f3dc12c3bb72696bda95418aca5.jpg from train to /content/filtered_dataset/train
# Copied 95_jpg.rf.1b509381947c2e2880581910b44f6f68.jpg from train to /content/filtered_dataset/train
# Copied 002_png_jpg.rf.737187b82338e515e70bdc1b7e67af16.jpg from train to /content/filtered_dataset/train
# Copied 3613744271_output_jpg.rf.bfa3f29647e9490a355c0e021c5e93e6.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-117-_jpg.rf.dbe251e37e5add5670962bbbe5314c2d.jpg from train to /content/filtered_dataset/train
# Copied bus-160-_jpg.rf.914e1c0916376f2799acab97c2b3e05b.jpg from train to /content/filtered_dataset/train
# Copied 1723730710587_jpg.rf.9f7b61f6f2eb38a80574ba3317b06f62.jpg from train to /content/filtered_dataset/train
# Copied 490_png_jpg.rf.717f88d52a2fbd6a70cde378da7aeafa.jpg from train to /content/filtered_dataset/train
# Copied Night-Bangladeshi-4K-Walking-Tour-2024-Chittagong-City-4K-Walking-Tour-2024_137_jpg.rf.4de8aefde0b667ddeee3e0cc25286a78.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_99_jpg.rf.561a8958b5cf6b3f1fed598287eedf56.jpg from train to /content/filtered_dataset/train
# Copied 0000149_jpg.rf.35fe6334e37435e6b44bebd41ca3c63a.jpg from train to /content/filtered_dataset/train
# Copied T101027_jpg.rf.df2fbfcb1c8beb6436e029bce7470d4b.jpg from train to /content/filtered_dataset/train
# Copied up58_output_jpg.rf.8e1fb695865823aa253ef44fd4f9c273.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_964_jpg.rf.1bbb6a4f6787e509b611245093b80246.jpg from train to /content/filtered_dataset/train
# Copied KakaoTalk_20220315_131835287_05_jpg.rf.0207dc57a4504576369296cac8fb229c.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-52-_jpg.rf.0b91fdce864fb3987c420fe676707a2a.jpg from train to /content/filtered_dataset/train
# Copied 021_png_jpg.rf.40b30d474dd14949cdd11113854029c1.jpg from train to /content/filtered_dataset/train
# Copied 960_jpg.rf.02bbcf55b50c26927c1f167e018902bd.jpg from train to /content/filtered_dataset/train
# Copied 000022_jpg.rf.b61db6c96bc147b4e7ef54afa8e2f372.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_33_jpg.rf.99a280f3dd41df751a2db8bea9ba89e0.jpg from train to /content/filtered_dataset/train
# Copied 166_png_jpg.rf.8b9e820def0a9aa971a0bb718f5e2177.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_376_jpg.rf.a94a2d9797f5d1fbd5259b84daaa74e0.jpg from train to /content/filtered_dataset/train
# Copied college-in-front28_jpg.rf.a6c7ddacc7fc9898bcc96d0a3e88cc22.jpg from train to /content/filtered_dataset/train
# Copied 112_jpg.rf.4bff9f734552bd3ede5b996d64dca1a2.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_29_jpg.rf.45c043723182d88b84ac67a003e5ffb3.jpg from train to /content/filtered_dataset/train
# Copied images158_jpg.rf.d73cdd4b19962973ae4d00dc4099182e.jpg from train to /content/filtered_dataset/train
# Copied images254_jpg.rf.25b3105770580127a570b71e5e7f77c2.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-603-_jpg.rf.6a6e2e4e5262f9fcaecf088c06d0b6a9.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-72-_jpg.rf.c731d4fface2a4143a5dc70efd3a13c4.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_166_jpg.rf.bacaac537f68d825de209f7c651d1548.jpg from train to /content/filtered_dataset/train
# Copied 000010_jpg.rf.ebd9dcc22d7c337c9a321ad436741c40.jpg from train to /content/filtered_dataset/train
# Copied image21_jpeg_jpg.rf.71089e5005dc70bc779ec21af7154b9e.jpg from train to /content/filtered_dataset/train
# Copied images208_jpg.rf.947852abc3e844a9d7ef91e82dac961f.jpg from train to /content/filtered_dataset/train
# Copied 766_original_jpg.rf.9ec48b321b65caf3593a441a18da8aeb.jpg from train to /content/filtered_dataset/train
# Copied image21_jpeg_jpg.rf.51843e5c7d58c4ebfd2243f8fb9b2d35.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_68_jpg.rf.fb66072c2cd47735e3247f90c3e466de.jpg from train to /content/filtered_dataset/train
# Copied horse-252-_jpg.rf.86aec3ba02032fb0e5e5433464d3e27b.jpg from train to /content/filtered_dataset/train
# Copied horse-443-_jpg.rf.77261bdedec5f2dea8c110068aa628d8.jpg from train to /content/filtered_dataset/train
# Copied 369_jpg.rf.1f30bfbdaa39c28fc432b4decdb1cc01.jpg from train to /content/filtered_dataset/train
# Copied 191_jpg.rf.2640474f7b905fed651b0d00003b0cad.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-72-_jpg.rf.cf8f3b614f4e1cc60d70047d5071bbda.jpg from train to /content/filtered_dataset/train
# Copied 2652437777_output_jpg.rf.37d2b060f37809f2d19afd3c8bb13989.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-8-_jpg.rf.4f3a53bc1165677b730ffcc8d84491d0.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-28-_jpg.rf.e6684d2cf1a84084210a3dfb373b24f1.jpg from train to /content/filtered_dataset/train
# Copied 473_jpg.rf.1f3d76e89a867a69e93c358b052e1e61.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_57_jpg.rf.181c5b37f052c806646485df97ed41a9.jpg from train to /content/filtered_dataset/train
# Copied 016_png_jpg.rf.f078efded354eff2b808bf29601a3e7e.jpg from train to /content/filtered_dataset/train
# Copied 167_jpg.rf.732682b7e4b00301c2e862f48b8e024f.jpg from train to /content/filtered_dataset/train
# Copied 238_jpg.rf.26b2b4acfa1acd0b24fa72265ee72e31.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-32-_jpg.rf.9a2c7f3cb5aabb3330aaf0332580f1eb.jpg from train to /content/filtered_dataset/train
# Copied 424_png_jpg.rf.042e92f302538c068e4fcee12e8fcb14.jpg from train to /content/filtered_dataset/train
# Copied 356_jpg.rf.d4ad0a1ac54f9d8b3f5ae50bb3b43eec.jpg from train to /content/filtered_dataset/train
# Copied 1219_jpg.rf.cce2aee36c2ac88f53a40927ca52c018.jpg from train to /content/filtered_dataset/train
# Copied bus-121-_jpg.rf.9d5e819fcc6f27df83abf798b900450b.jpg from train to /content/filtered_dataset/train
# Copied 65_png_jpg.rf.6826b6d5477106774dd6b011c047ad17.jpg from train to /content/filtered_dataset/train
# Copied 109_png.rf.1f4976e56e9fe3c66a796016781c6340.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-78-_jpg.rf.987903399bdf839486e47aef15926ff7.jpg from train to /content/filtered_dataset/train
# Copied T111126_jpg.rf.2cf2b30d4e1ec7c2daac3db66ecc0d03.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-63-_jpg.rf.3a7a5ea81b93cb628b830d2218797a7a.jpg from train to /content/filtered_dataset/train
# Copied a2_038_jpg.rf.c557c52073202b34f748905eecdf2fbb.jpg from train to /content/filtered_dataset/train
# Copied 00045_07_jpg.rf.f95b0247be0fcdc153ccae6854d556b9.jpg from train to /content/filtered_dataset/train
# Copied 4869334632_output_jpg.rf.d33f96d22ddd32b00ddd878631c0795e.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-20-_jpg.rf.16121dae2379962bf1989e8ca2846cce.jpg from train to /content/filtered_dataset/train
# Copied 0000421_r_jpg.rf.e1048035656d0c933d25744ac0e6c766.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-131-_jpg.rf.0ac28019e614d92c6e29097d801828a9.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_927_jpg.rf.a7da1b2f2c1beba19bb143fc9acb2aa2.jpg from train to /content/filtered_dataset/train
# Copied images164_jpg.rf.73e0456a0669164c4a13bacd0e9a34da.jpg from train to /content/filtered_dataset/train
# Copied close-up-big-pothole-with-dirty-rain-water-road_127089-4714_jpg.rf.f52f337faa124eeb175b0345296b46d9.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_919_jpg.rf.ab5ff394ad524144ecae2086588877c2.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_83_jpg.rf.2681693bb23ea3ddcc22309b02435e12.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_260_jpg.rf.015ac4667b5d3c091c161100c29468b8.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_82_jpg.rf.7ef81cdc7670de2fb6bc67327dfbc787.jpg from train to /content/filtered_dataset/train
# Copied close-up-big-pothole-with-dirty-rain-water-road_127089-5185_jpg.rf.85a05e9a2b63b7bbe23409b6860b866f.jpg from train to /content/filtered_dataset/train
# Copied images137_jpg.rf.1b08c3c8a8d2f858d5dc20f84ecd16e5.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-174-_jpg.rf.bf1e963e818821e2e50415400eefdc4b.jpg from train to /content/filtered_dataset/train
# Copied images255_jpg.rf.ecfaf0405de93cc58676f8023d57e33d.jpg from train to /content/filtered_dataset/train
# Copied 5155847970_output_jpg.rf.024e7be20e73556373a2c361c0b66d02.jpg from train to /content/filtered_dataset/train
# Copied 27822998_web1_220122-HSL-Potholes_1_jpg.rf.7cb006a11e91750f7f9cf47ae6870e27.jpg from train to /content/filtered_dataset/train
# Copied 0002910_jpg.rf.a4c4c8008c2c6085c0bab5a57e113bce.jpg from train to /content/filtered_dataset/train
# Copied 323_jpg.rf.fc57f4ae86324185e6406076af2fdb40.jpg from train to /content/filtered_dataset/train
# Copied IMG_20210920_155453_output_jpg.rf.fdecf077c86952a8d25a3f895ec86773.jpg from train to /content/filtered_dataset/train
# Copied bus-175-_jpg.rf.f4c28abdbef605902647cfbbde39f18c.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_11_jpg.rf.26e13ccf3890d121d6f699100c2e42bb.jpg from train to /content/filtered_dataset/train
# Copied 74f4b77d-Datacluster_Auto_140_jpg.rf.4c7c163d6cbecdf97f64d31f6a87ea79.jpg from train to /content/filtered_dataset/train
# Copied IMG_0482_jpg.rf.c06a4b0ff6ca682ff05a14386bb3b657.jpg from train to /content/filtered_dataset/train
# Copied T111463_jpg.rf.9d2e1820eb5bd52b66e32978cf517ad3.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_7_jpg.rf.737fe47ffcfccf213a01ce6f51f26588.jpg from train to /content/filtered_dataset/train
# Copied 1071_jpg.rf.b66a4f9652e5a29d7ff472dd4e7cf79c.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-61-_jpg.rf.abd1e33a63ab620a141e5e315c505e81.jpg from train to /content/filtered_dataset/train
# Copied 1-9-_jpg.rf.2c7d6d21f5396b3da2722282add3f0aa.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-10-_jpg.rf.d87351a8dee04c8e5683915b1f7a58ac.jpg from train to /content/filtered_dataset/train
# Copied 227_jpg.rf.d1d218be90645594c1d50550af841cb5.jpg from train to /content/filtered_dataset/train
# Copied 277_jpg.rf.20ee042f724215548b3828e54e6c607a.jpg from train to /content/filtered_dataset/train
# Copied 220_jpg.rf.91cc71d8632087462d75b09c0d1099e5.jpg from train to /content/filtered_dataset/train
# Copied a2_289_jpg.rf.32a9161473f3e5cc7ddbf9afbefe5100.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_100_jpg.rf.2b695b84b999eb877842073c4dbf011d.jpg from train to /content/filtered_dataset/train
# Copied 515_jpg.rf.e02c86886724b150b9393935b4b6deee.jpg from train to /content/filtered_dataset/train
# Copied T111761_jpg.rf.d425e3ca928ffdbac869cc01feb9a12c.jpg from train to /content/filtered_dataset/train
# Copied Night-Bangladeshi-4K-Walking-Tour-2024-Chittagong-City-4K-Walking-Tour-2024_187_jpg.rf.474a09d450b20a8789bf48ffa115a8ff.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-512-_jpg.rf.6801429887a69b9622f3fb612bb46853.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-67-_jpg.rf.cc42af7c5731ea7b7219bd0256913c67.jpg from train to /content/filtered_dataset/train
# Copied T112436_jpg.rf.c6a23bacc3c2cadf76ea8d5278ac0543.jpg from train to /content/filtered_dataset/train
# Copied images224_jpg.rf.8da12a53dd8fc0c3db7505bbf5636ce1.jpg from train to /content/filtered_dataset/train
# Copied 1245_jpg.rf.2425b500151fdef399eb9d341e7c79ea.jpg from train to /content/filtered_dataset/train
# Copied images252_jpg.rf.e5a95bf2690cc0f35ebc2da0ebd4f9e7.jpg from train to /content/filtered_dataset/train
# Copied 0008685_jpg.rf.c82eb206506a701df6e75145e183e181.jpg from train to /content/filtered_dataset/train
# Copied 4103470552_output_jpg.rf.efb250b7dcc6f0247187108c9c757b2b.jpg from train to /content/filtered_dataset/train
# Copied 179_png_jpg.rf.40a3d9aa5106d3c0ecc4acfbd4b8eab7.jpg from train to /content/filtered_dataset/train
# Copied 270_jpg.rf.30bfca1bcdd94aa6b73aaf450730df29.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-23-_jpg.rf.9a367851c6e63f5565b28dc8fd974b08.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-32-_jpg.rf.1b5257c2e2f48c9f9338c4a1a4a3eed4.jpg from train to /content/filtered_dataset/train
# Copied SAHED-7-_jpg.rf.ff27e656fd8dbbfe96bc4ca1da99e232.jpg from train to /content/filtered_dataset/train
# Copied 51_jpg.rf.6c6ae258610a8b1b019c23ce3d81968f.jpg from train to /content/filtered_dataset/train
# Copied 1200px-Shoushan_National_Nature_Park-Created_by_Nora_jpg.rf.eaaceeb56691d7668894e87426be5349.jpg from train to /content/filtered_dataset/train
# Copied 020_png_jpg.rf.5d0decec04ae4e2f4c9748d23e00e6a0.jpg from train to /content/filtered_dataset/train
# Copied 1723730713405_jpg.rf.36b005930058f44f4a9c20f632c770a2.jpg from train to /content/filtered_dataset/train
# Copied IMG_20210920_114223_output_jpg.rf.6ff33e5b724bfac2585f6e567f0eda18.jpg from train to /content/filtered_dataset/train
# Copied 1723730712137_jpg.rf.08c36ee4d233f470681d8fac30a5f998.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_316_jpg.rf.e7bc063d5bcdd43ab66e132049fba90e.jpg from train to /content/filtered_dataset/train
# Copied 443_jpg.rf.eafe04900f8cee3525c12934dc74002a.jpg from train to /content/filtered_dataset/train
# Copied 243_jpg.rf.205bf3dc9b0110fa8b6bad96ce32313a.jpg from train to /content/filtered_dataset/train
# Copied a2_167_jpg.rf.d6c9bf8f9f51c265f8c0537dac4b1d1c.jpg from train to /content/filtered_dataset/train
# Copied images-48-_jpg.rf.8f703be9f32dff8206b1fb986871eda8.jpg from train to /content/filtered_dataset/train
# Copied 169_jpg.rf.7f608bec95fb7a2f45f63f17c7a72cdb.jpg from train to /content/filtered_dataset/train
# Copied crossroad28_jpg.rf.3a861970f47c3e3d6c3430808f930c87.jpg from train to /content/filtered_dataset/train
# Copied images179_jpg.rf.1c329dea1c168d9ee85e936f93366738.jpg from train to /content/filtered_dataset/train
# Copied Canadian-National-Freight-Train-3D_jpg.rf.0879c9ec1089d05ef0bf3095c41000bf.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-229-_jpg.rf.cd567adaa08b02c1bde4aacbdc592140.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-62-_jpg.rf.0abe4b29526df810955390d907bd7a30.jpg from train to /content/filtered_dataset/train
# Copied T011000_jpg.rf.1d8c38e9e146ca92526453fa2ae52819.jpg from train to /content/filtered_dataset/train
# Copied images219_jpg.rf.ecbb435ea9ad06d63afbdf07041664a9.jpg from train to /content/filtered_dataset/train
# Copied images155_jpg.rf.9143efcd7dc721b0de8e64959f251d4a.jpg from train to /content/filtered_dataset/train
# Copied 000071_jpg.rf.75474ce4128a0120f322369c35e2aa2b.jpg from train to /content/filtered_dataset/train
# Copied a2_088_jpg.rf.891cdbcf559ea994fb9474d978ce307f.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_669_jpg.rf.ed543d959ab14923ba688b03bbc08c7a.jpg from train to /content/filtered_dataset/train
# Copied T301048_jpg.rf.b908ff55a402f05fba3f2a500ae202a8.jpg from train to /content/filtered_dataset/train
# Copied 00008_00_jpg.rf.43611e579077e6f428d7474c020daf2b.jpg from train to /content/filtered_dataset/train
# Copied PEDC-7-_png.rf.6b7cc9a6dac849e6c8229fc45f16cdfe.jpg from train to /content/filtered_dataset/train
# Copied 1723730712430_jpg.rf.d8f04ecbc1ddaa34bed54d1f2bede9d6.jpg from train to /content/filtered_dataset/train
# Copied photo_2023-11-17_21-09-14_jpg.rf.962e5bf3a75812431e68f85a01987e02.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-377-_jpg.rf.7ce2082f287c759ab7f17f4e40ed6670.jpg from train to /content/filtered_dataset/train
# Copied 312_jpg.rf.43b442618d8426abf74a7b37f34054af.jpg from train to /content/filtered_dataset/train
# Copied images173_jpg.rf.4c1ea3417c465b49b34f4a46a0fd677f.jpg from train to /content/filtered_dataset/train
# Copied 412_png_jpg.rf.c6ffff38fcf8622d5aa0cb938529a9f5.jpg from train to /content/filtered_dataset/train
# Copied Autorickshaw-140-_jpg.rf.8efbe99f8458fd95e1e25743fa8737b0.jpg from train to /content/filtered_dataset/train
# Copied images199_jpg.rf.3aeeff30b2d10f4de1ddf1c83eac9f2d.jpg from train to /content/filtered_dataset/train
# Copied VID_20230225_135853_000022_jpg.rf.fe5ab931e35405b1c57cf56ff3b61621.jpg from train to /content/filtered_dataset/train
# Copied 1723730711118_jpg.rf.145cfe0429535ca0e492ff5ad314bd1a.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-20-_jpg.rf.f9ebd6e6122d1975ffb022de2667ed70.jpg from train to /content/filtered_dataset/train
# Copied 142_jpg.rf.bbdb81cf5019434b3199b91c97878faa.jpg from train to /content/filtered_dataset/train
# Copied 000008_jpg.rf.bf8d096f7eb7c830e9a090ff2a092260.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_55_jpg.rf.39ad1a3e0b1566a0dc66c0e067ddde38.jpg from train to /content/filtered_dataset/train
# Copied bus-166-_jpg.rf.e43f5a61d92ebf817493c8cdeb48b78d.jpg from train to /content/filtered_dataset/train
# Copied 397_jpg.rf.1842b56fe792e0b98fdaf7224fa732fa.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-64-_jpg.rf.21dfffa37d95570e27e3dc3cca9ff80d.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-115-_jpg.rf.37bb7f111ae2927c7653028f45d85e71.jpg from train to /content/filtered_dataset/train
# Copied 473_png_jpg.rf.e3c98df8fd1e435bdc203933f7000ea3.jpg from train to /content/filtered_dataset/train
# Copied crossing32_jpg.rf.9c8b6a472445596c3d9d4cd3cb7d5f65.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-67-_jpg.rf.ce741f73ad496f793b43f35403119768.jpg from train to /content/filtered_dataset/train
# Copied bollard-75-_jpg.rf.32d778f98ab6b1c3642d11de49c8a678.jpg from train to /content/filtered_dataset/train
# Copied 1048_jpg.rf.27e13a33316d3f2a79e575f0c585adca.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_30_jpg.rf.f2353d248520e41530e0ed23372130e8.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-816-_jpg.rf.a61c25c465be0a378ca1d0e806c95878.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_738_jpg.rf.f2a051d97a88286fe0216f841031b6af.jpg from train to /content/filtered_dataset/train
# Copied 939_original_jpg.rf.0f381e6e51523e3001dcf66765b7ec51.jpg from train to /content/filtered_dataset/train
# Copied 1-7-_jpg.rf.3480dfa3422e8193ed76aeb5f09a5e9f.jpg from train to /content/filtered_dataset/train
# Copied 128_jpg.rf.2de2605dc11a39b38b3f15f22c5b1e11.jpg from train to /content/filtered_dataset/train
# Copied download-13-_jpg.rf.f88b722adfddba5436755c8ce350317c.jpg from train to /content/filtered_dataset/train
# Copied 1723730713446_jpg.rf.fa28a10fdb03434517634a0baf9ead83.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_15_jpg.rf.f504626aafcb0de0564c05dfdbd5d2db.jpg from train to /content/filtered_dataset/train
# Copied crossroad19_jpg.rf.580c292fea5a0ee13a169e8099979dae.jpg from train to /content/filtered_dataset/train
# Copied 308_jpg.rf.cbb8d80362f605fca50f252f4211be0c.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-72-_jpg.rf.a7bb56279f59f5d44626a4f0bb0f9993.jpg from train to /content/filtered_dataset/train
# Copied 210_jpg.rf.39c50294cb150a993083a965ff52e945.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_217_jpg.rf.1f5b02501e888ff6727a17496c86e0b9.jpg from train to /content/filtered_dataset/train
# Copied 210_jpg.rf.cf3939cea109365f7503b14d272b9318.jpg from train to /content/filtered_dataset/train
# Copied 321211354_output_output_jpg.rf.235579d8f1b91c4488ad98e11fbb597d.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-592-_jpg.rf.095d62435397d1f24b93de7d7eebcf11.jpg from train to /content/filtered_dataset/train
# Copied PXL_20231014_072036057_jpg.rf.b898fe168c87feed3c39863ea18914ba.jpg from train to /content/filtered_dataset/train
# Copied bus-117-_jpg.rf.89187bb5deb9423e2d1e12356b9b3f78.jpg from train to /content/filtered_dataset/train
# Copied T301038_jpg.rf.d6dd412035ac003de819f7bbce0232ec.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_27_jpg.rf.123bd3c504c40c64492522d7d77285c1.jpg from train to /content/filtered_dataset/train
# Copied IMG-20210903-WA0016flip_output_output_jpg.rf.352128895c053c4ee766e670128df78a.jpg from train to /content/filtered_dataset/train
# Copied 174_jpg.rf.a8b5c47ed0ff7d4198b01326f141f4c4.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_88_jpg.rf.489a50e52558eb246e90c6e5fc04ba05.jpg from train to /content/filtered_dataset/train
# Copied 436_jpg.rf.fbbd8f228359752d94d3a95e98def8d4.jpg from train to /content/filtered_dataset/train
# Copied images211_jpg.rf.a5709fe38d059ee4abe001f7f4e53e70.jpg from train to /content/filtered_dataset/train
# Copied 415_png_jpg.rf.0361f578f2b5bcd0b68523d9f267e65f.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_392_jpg.rf.bcc66a12177494459c617d96e2337d14.jpg from train to /content/filtered_dataset/train
# Copied 189_png_jpg.rf.6ffef2f8c6229ea7c54ee4f2b56cdc7a.jpg from train to /content/filtered_dataset/train
# Copied 158_jpg.rf.e4f9019db27e867e06c4e3ceefb58c28.jpg from train to /content/filtered_dataset/train
# Copied 4557020600_output_jpg.rf.ba3b2a38c047333c82d835702ea01f8c.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_35_jpg.rf.31eae1bbf4019ed58cab689ad2c147c5.jpg from train to /content/filtered_dataset/train
# Copied images137_jpg.rf.4d1a483dc7d818501b99572c28fc8f48.jpg from train to /content/filtered_dataset/train
# Copied bus-150-_jpg.rf.079482732a9f0f02632a7cedde9c28ab.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_147_jpg.rf.4f13b6a1b2b387e32ecb44007a81a64f.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_110_jpg.rf.917178a339dccb1cb71bb4976ea4777a.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-137-_jpg.rf.6e9ef836b41c9cd3e79bd4ddd3d2787d.jpg from train to /content/filtered_dataset/train
# Copied 21_jpg.rf.47334fafe6272686ef6a89b398f68a43.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_21_jpg.rf.b2718fa85e6e6153e83df15687d70ae3.jpg from train to /content/filtered_dataset/train
# Copied 26513366c3ef6a08_output_jpg.rf.90c2e15a8af8bcb90b4eff8eb7093e54.jpg from train to /content/filtered_dataset/train
# Copied 116_jpg.rf.0b4fd9f004db33effa7d90537e2980cd.jpg from train to /content/filtered_dataset/train
# Copied images233_jpg.rf.abaa46bca7c415d13f1850a70738ad98.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-498-_jpg.rf.ad0fc9da6910efd5f416f4301d9ac6db.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-12-_jpg.rf.3c4eb51a6e873bfb0aed9c2a9af378e5.jpg from train to /content/filtered_dataset/train
# Copied 138_jpg.rf.6642876e9701e13e2a4bb099ff6cf492.jpg from train to /content/filtered_dataset/train
# Copied 1277_jpg.rf.ca8f715acf2cf14dc6c97b1fed601499.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_96_jpg.rf.e651fcd1fcfe7bea944e4236a71cfdc3.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-66-_jpg.rf.513de4f250655f3e489938bf1729f5c6.jpg from train to /content/filtered_dataset/train
# Copied images233_jpg.rf.eb0e2945ddaa897d0d512079fcbbfc40.jpg from train to /content/filtered_dataset/train
# Copied T111002_jpg.rf.d3aa8e2e8d99aef333d6d26ad88ed67c.jpg from train to /content/filtered_dataset/train
# Copied bus-115-_jpg.rf.e6b7a36ae5352f894dcac8358c212acc.jpg from train to /content/filtered_dataset/train
# Copied images255_jpg.rf.fea3f6fa0363a988d9177581a635e950.jpg from train to /content/filtered_dataset/train
# Copied a2_043_jpg.rf.dad4ca046275340fb267828d681c49b9.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_161_jpg.rf.33fa54108c2300c13c5bf9070e64cc4c.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-24-_jpg.rf.264150ddf3aba57b79647b78869bbda4.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_146_jpg.rf.ba021bc2ac9aa84273484f0922602b99.jpg from train to /content/filtered_dataset/train
# Copied crossroad-with-a-side-road-on-the-left11_jpg.rf.b9657bbfde84716138304b6387e72624.jpg from train to /content/filtered_dataset/train
# Copied IMG_0533_jpg.rf.ba567a9276499f4b5c4c23952f3b65f7.jpg from train to /content/filtered_dataset/train
# Copied images224_jpg.rf.cd74dab0b3e46077f5e013e09fabde2c.jpg from train to /content/filtered_dataset/train
# Copied 10793618065_0beb7f728a_b_jpg.rf.d0481467ea63a8dea156dec12b53b882.jpg from train to /content/filtered_dataset/train
# Copied 465_jpg.rf.a31a22d70cc0db54034f8a818093536e.jpg from train to /content/filtered_dataset/train
# Copied T111335_jpg.rf.8dd0eed9a67640f217ff3169c947b79d.jpg from train to /content/filtered_dataset/train
# Copied 000388_jpg.rf.dcc6f2d52ce6509a5721193d382dd225.jpg from train to /content/filtered_dataset/train
# Copied T111033_jpg.rf.05d50d3fc478f1de9e7ceba742bdfcb8.jpg from train to /content/filtered_dataset/train
# Copied T111147_jpg.rf.a714ddce16771f79a4ca60b8c5662e57.jpg from train to /content/filtered_dataset/train
# Copied 000305_jpg.rf.d02fc29db630f9a325918d07434790fd.jpg from train to /content/filtered_dataset/train
# Copied 975_jpg.rf.d68e257301c77b5b2ed71a50b09b9b46.jpg from train to /content/filtered_dataset/train
# Copied T112295_jpg.rf.e2644ffa0ef2f26bbb8b8651a800cbb6.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_192_jpg.rf.275d4a3791deb144e4a7806472fb5891.jpg from train to /content/filtered_dataset/train
# Copied file-20221017-15-drdtr5_jpg.rf.b7d23db2fee6a13b3410615fdeca8564.jpg from train to /content/filtered_dataset/train
# Copied IMG_0559_jpg.rf.99a6a4e6473bcfcd0c9ffde0f7a39f28.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_114_jpg.rf.30d17df0626a877f124bfad5be1a9556.jpg from train to /content/filtered_dataset/train
# Copied 0002393_jpg.rf.2effb8168e96cd6839917bdc32872a18.jpg from train to /content/filtered_dataset/train
# Copied Capture_JPG.rf.64fcb0a53c8547fd60f5427a866df31a.jpg from train to /content/filtered_dataset/train
# Copied 246_jpg.rf.145fe71e36d83505dac3bf155050920f.jpg from train to /content/filtered_dataset/train
# Copied photo_2023-11-17_21-01-55_jpg.rf.25b2faecfd166e3efba2b04789527d57.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-26-_jpg.rf.a127a9343870b205eb090ad4971c0694.jpg from train to /content/filtered_dataset/train
# Copied 477_jpg.rf.74fd03137ae288d0746e80e9438f1bd1.jpg from train to /content/filtered_dataset/train
# Copied a2_067_jpg.rf.d0754b7b0ea5dc3721cb7f79d42d0d7d.jpg from train to /content/filtered_dataset/train
# Copied IMG_0562_jpg.rf.ae6332d2b37b50101a157f11f67f1422.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_133_jpg.rf.3d58ba5e8bc454a3e80d168cbb47f8ab.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-813-_jpg.rf.e47cde7d01081d428a4bf26246b80801.jpg from train to /content/filtered_dataset/train
# Copied T011005_jpg.rf.e1c4dc88b24e4af4bfc3dc72c5089a1e.jpg from train to /content/filtered_dataset/train
# Copied PXL_20231014_071453533_jpg.rf.c892af06820b0ed991b4ac00edc5478c.jpg from train to /content/filtered_dataset/train
# Copied bollard-76-_jpg.rf.1d5aa547f3d321828fe04a22122d70b9.jpg from train to /content/filtered_dataset/train
# Copied images17_jpg.rf.7f96049386f159026cd183a3d9d239bf.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_301_jpg.rf.7c2e7c39945ef760990d4d52afeac680.jpg from train to /content/filtered_dataset/train
# Copied 5375204548_output_jpg.rf.10f9989b02098193c3c655f9d288405f.jpg from train to /content/filtered_dataset/train
# Copied T101002_jpg.rf.57a1edb7c7155e274e9ba93c4d5a3929.jpg from train to /content/filtered_dataset/train
# Copied 1101_jpg.rf.bf8c51c8bb964e26eb059c5980aa1787.jpg from train to /content/filtered_dataset/train
# Copied a2_254_jpg.rf.b640ae12d49deb787c1f34579bbe29a5.jpg from train to /content/filtered_dataset/train
# Copied 149_jpg.rf.b219d54df239573d3874d55634e32d5f.jpg from train to /content/filtered_dataset/train
# Copied 1180_jpg.rf.c1c2ed30b8e3d87f7bb1fc89620f6f99.jpg from train to /content/filtered_dataset/train
# Copied 151_jpg.rf.498e6f67b423f3bfa73fa4fddeca6db2.jpg from train to /content/filtered_dataset/train
# Copied a2_265_jpg.rf.c667a86c6f04f40e2f55496696e71b06.jpg from train to /content/filtered_dataset/train
# Copied horse-101-_jpg.rf.01e1daeba4b28035d0e479a8e5a236bc.jpg from train to /content/filtered_dataset/train
# Copied 199_jpg.rf.bf2c5198ea378a2eacc9a235ce449fb1.jpg from train to /content/filtered_dataset/train
# Copied T111070_jpg.rf.6143c6054619226f3e18d397f68adb7b.jpg from train to /content/filtered_dataset/train
# Copied IMG-20210920-WA0002flip_output_jpg.rf.a67abab92958751fbb73e131f871a511.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-136-_jpg.rf.24b8d1bbc733eb72f3fecce6bce5e9a0.jpg from train to /content/filtered_dataset/train
# Copied T112247_jpg.rf.86bd2a3604bf585046f41995e1adb36d.jpg from train to /content/filtered_dataset/train
# Copied f791b832-Datacluster_Auto_69_jpg.rf.540763977b1a4e853f48aae22fb6a489.jpg from train to /content/filtered_dataset/train
# Copied T021025_jpg.rf.bc5a184e5b5dd68489c515a7cf15bda3.jpg from train to /content/filtered_dataset/train
# Copied 394_jpg.rf.3189ec1ce568862ff1d26a9c449ea433.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_437_jpg.rf.ee05e6d86e32f1e763ae42dc0cdf38bf.jpg from train to /content/filtered_dataset/train
# Copied 001_png_jpg.rf.f487e9c37348e43b1744a89c04c70ca3.jpg from train to /content/filtered_dataset/train
# Copied 248_jpg.rf.db931c247866d33766fd46804c2ff9ba.jpg from train to /content/filtered_dataset/train
# Copied 199_png_jpg.rf.4d4f3206ca020d7d86874570dd005fc7.jpg from train to /content/filtered_dataset/train
# Copied 90_png_jpg.rf.bf2a07b649e1b5f75dd0e4c46ea08754.jpg from train to /content/filtered_dataset/train
# Copied bollard-74-_jpg.rf.d06df594f06678435abc65312a97a732.jpg from train to /content/filtered_dataset/train
# Copied bus-164-_jpg.rf.19e5d61c1694620cc050a0d35c43cb70.jpg from train to /content/filtered_dataset/train
# Copied photo_2023-11-17_20-47-13_jpg.rf.bf37799729dddf26e788da773a12cfb4.jpg from train to /content/filtered_dataset/train
# Copied 1221_jpg.rf.ab542a5b41b02161762d8ccedff6ce61.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_739_jpg.rf.09e1b7d89b158da211bf8daac0ce3e8c.jpg from train to /content/filtered_dataset/train
# Copied images219_jpg.rf.50ce0036008b580ca35dc45af2ee14ab.jpg from train to /content/filtered_dataset/train
# Copied 000209_jpg.rf.d4b0d4e577c5beba2b0127b25992a06f.jpg from train to /content/filtered_dataset/train
# Copied a2_063_jpg.rf.f6d5c4f24388fc2bb5bc6d7073ee9427.jpg from train to /content/filtered_dataset/train
# Copied 026_png_jpg.rf.a549731274771b83e8d29694f49eec25.jpg from train to /content/filtered_dataset/train
# Copied 1ffe557e-Datacluster_Auto_143_jpg.rf.293e0c85e6b5f2dc507fb9a80f441ced.jpg from train to /content/filtered_dataset/train
# Copied 314_jpg.rf.5465999670fb6c97e5fd067dce11dea9.jpg from train to /content/filtered_dataset/train
# Copied 000037_jpg.rf.7e7dcb3ab232e395a8ac29920c237772.jpg from train to /content/filtered_dataset/train
# Copied 120_jpg.rf.d328b30666929f0bf706afd07fee59ae.jpg from train to /content/filtered_dataset/train
# Copied IMG_20181004_164700_jpg.rf.a9b6364fef83c2010ab6824bb1576e59.jpg from train to /content/filtered_dataset/train
# Copied T111083_jpg.rf.fbc7ba875724e03becb53e0d64a6108a.jpg from train to /content/filtered_dataset/train
# Copied 1200_jpg.rf.68e4bca9bd930dda98ece5d49710e51d.jpg from train to /content/filtered_dataset/train
# Copied 32_output_jpg.rf.cbc47b4410fde9465577ae6d1c3473f5.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-23-_jpg.rf.d0853ea8dcb43b8904350ca22af4a10b.jpg from train to /content/filtered_dataset/train
# Copied 75_jpg.rf.e49214e3213a0ad0122013d9ee4c06c2.jpg from train to /content/filtered_dataset/train
# Copied image31_jpeg_jpg.rf.0cf9469787e8582fed02b95914e150dd.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-138-_jpg.rf.283d01f33e6271ca986a196f459803bf.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_306_jpg.rf.c2d9360c2135cd0b8bdcffaadc323450.jpg from train to /content/filtered_dataset/train
# Copied bus-106-_jpg.rf.b8920666288a761464d131055a57d905.jpg from train to /content/filtered_dataset/train
# Copied 20flip_output_jpg.rf.9a85e2fcff2331c02777c8ba7f1b5109.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_302_jpg.rf.fd571b7e18b251ab4c30346e439b2290.jpg from train to /content/filtered_dataset/train
# Copied 401_png_jpg.rf.0f30f9f181b1992d96e72305c13687d2.jpg from train to /content/filtered_dataset/train
# Copied c843-water-barrier-side-0-1-1800x1200_jpg.rf.66f7a45e8fdbf84ecf291a5aba30d9d8.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_201_jpg.rf.eb78d6018c0e927d110a2d606212331a.jpg from train to /content/filtered_dataset/train
# Copied 201_jpg.rf.394dd134a956aba17596959bdb00644a.jpg from train to /content/filtered_dataset/train
# Copied 110_jpg.rf.691fa0ca8f3bbdcf2a1ef14614b82459.jpg from train to /content/filtered_dataset/train
# Copied 121_png_jpg.rf.e2a4c5974f9dc094a6409850d658e59e.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-11-_jpg.rf.a42ebeba6020cc29fedd705bb6abf4de.jpg from train to /content/filtered_dataset/train
# Copied file76ygewan406696193rz-1567618964_jpg.rf.260454b66fbfaaa46fb8099a3e61013c.jpg from train to /content/filtered_dataset/train
# Copied T101047_jpg.rf.1ffac6973e0aab96e6f0a9b436281556.jpg from train to /content/filtered_dataset/train
# Copied 4291007900_output_jpg.rf.a04a6e292b5feacd0df0aafc00d34d3a.jpg from train to /content/filtered_dataset/train
# Copied 299_png_jpg.rf.7bfbbe9397adad4d24d900387585aedd.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-233-_jpg.rf.c625ce75dc6dd994146fdebe07f533a4.jpg from train to /content/filtered_dataset/train
# Copied image25_jpeg_jpg.rf.2e188db39521c732cef5d66598a63eb3.jpg from train to /content/filtered_dataset/train
# Copied bus-110-_jpg.rf.912629194554941302949f159effacc8.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-29-_jpg.rf.dc07a38928abd48475e2de20f862590c.jpg from train to /content/filtered_dataset/train
# Copied 5efbea43-Datacluster_Auto_92_jpg.rf.f441ccf98c4253785ebf35e2d64b92ff.jpg from train to /content/filtered_dataset/train
# Copied T111015_jpg.rf.2b72ddf8b5e42b5d8a8ed92ec976ed3d.jpg from train to /content/filtered_dataset/train
# Copied 603_jpg.rf.6574e82c17f7b14f2d76dfa1a046c22e.jpg from train to /content/filtered_dataset/train
# Copied 103_jpg.rf.fe6e4a12747bb8f080d47986d1fd4d25.jpg from train to /content/filtered_dataset/train
# Copied images220_jpg.rf.4b098104c471b3a02c0a339289e846be.jpg from train to /content/filtered_dataset/train
# Copied 101_jpg.rf.abb7b3693eb75ea6e93489a70539e19c.jpg from train to /content/filtered_dataset/train
# Copied 026_png_jpg.rf.9c80c7cfdd3eeed785c738676f497354.jpg from train to /content/filtered_dataset/train
# Copied 000063_jpg.rf.d04d31a1c8d917dac971119a390fb657.jpg from train to /content/filtered_dataset/train
# Copied 59_jpg.rf.4e0f4fa8322b017730183aeb83c02649.jpg from train to /content/filtered_dataset/train
# Copied a2_079_jpg.rf.d9feb4683851762f203c375926202b3f.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_884_jpg.rf.ef1e97ba62bbaf644a3d3c4503093dcb.jpg from train to /content/filtered_dataset/train
# Copied a2_046_jpg.rf.349bb8d07b190e87e02f1712c0f6c2a1.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_161_jpg.rf.a0bf722c7284065f7b8e6526efa98a99.jpg from train to /content/filtered_dataset/train
# Copied 5537254831_output_jpg.rf.05ea8383abc393330f9f776c71711e3d.jpg from train to /content/filtered_dataset/train
# Copied 184_jpg.rf.bd45c3e49b7e59f39583f1617955a24d.jpg from train to /content/filtered_dataset/train
# Copied 451_png_jpg.rf.02cc63b26db23ed01ed1be23b4493955.jpg from train to /content/filtered_dataset/train
# Copied download-12-_jpg.rf.1b321359c4439a5b3529bc357c49ddf8.jpg from train to /content/filtered_dataset/train
# Copied T112450_jpg.rf.db14d81703c20f00b2455eab3fdcfd3e.jpg from train to /content/filtered_dataset/train
# Copied T111248_jpg.rf.9bc1c4b1f1dd20e1d47c29b2aa066cce.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-816-_jpg.rf.5a8ff2b370a9e91b82b10151f5795259.jpg from train to /content/filtered_dataset/train
# Copied 189507627_157645699711968_2421561461657402546_n_jpg.rf.143e42c0922ff70be80583f21b83bd7f.jpg from train to /content/filtered_dataset/train
# Copied IMG_20180821_220408_jpg.rf.3848c43b1fb56644b3b880f18d83e0eb.jpg from train to /content/filtered_dataset/train
# Copied 130_jpg.rf.abafdd2d81c69b5d2df0122967b5cd20.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_897_jpg.rf.84a02bd842f0185de473c46099c4b899.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-643-_jpg.rf.6100ce7fc319ce9060b01949f62bdfda.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-71-_jpg.rf.0c06a74364fab3f4c4885118e767145e.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_15_jpg.rf.51263b90c67b35a021dde1f4a76df46f.jpg from train to /content/filtered_dataset/train
# Copied 536_jpg.rf.ee540b7a812fc756fe9fd47760da9d79.jpg from train to /content/filtered_dataset/train
# Copied 81_png_jpg.rf.07e88afb3cff3301344270604b553aab.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-28-_jpg.rf.a1e23ce7c0533cb95e604e981aa4358d.jpg from train to /content/filtered_dataset/train
# Copied 260_png_jpg.rf.9848df3fd008f6eea414229dbc9b5e86.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_29_jpg.rf.77b9e5123dd9ade5afce09c226f5f18c.jpg from train to /content/filtered_dataset/train
# Copied 027_png_jpg.rf.b0be7dc9bcd75ef02d545d70f5392771.jpg from train to /content/filtered_dataset/train
# Copied images208_jpg.rf.0ab22a15af06b8fd087434100d6e4853.jpg from train to /content/filtered_dataset/train
# Copied 1723730712788_jpg.rf.42e7d77b964e225d008af21d4e1ab929.jpg from train to /content/filtered_dataset/train
# Copied 186_jpg.rf.a0be9a610cb6182e722b81e8e38ed96d.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-18-_jpg.rf.8edd80f0c6c009f3ee9595106c75c616.jpg from train to /content/filtered_dataset/train
# Copied 000107_jpg.rf.0a293cc10b3a5f1db2f2c992a23eeba5.jpg from train to /content/filtered_dataset/train
# Copied image21_jpeg_jpg.rf.df6e007bf9308984ef2225226b507c60.jpg from train to /content/filtered_dataset/train
# Copied 184_jpg.rf.7991794c99194e3c73a996fac4d2cd3f.jpg from train to /content/filtered_dataset/train
# Copied 495_png_jpg.rf.1afd7bef32c7eef8a4111d32eccb3718.jpg from train to /content/filtered_dataset/train
# Copied youtube-5_jpg.rf.baed5659a93340cd0354d366a7b65d4f.jpg from train to /content/filtered_dataset/train
# Copied 552_png_jpg.rf.616c8b473c40482fae7dabb021be375c.jpg from train to /content/filtered_dataset/train
# Copied 143_jpg.rf.5884e45317b187752755d37642016f5f.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-78-_jpg.rf.cdc9d3f1728ee45b394d7c00be45ef06.jpg from train to /content/filtered_dataset/train
# Copied 170_jpg.rf.6daa24588a6955a7df78a338c73d5c02.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_125_jpg.rf.5dc9b40ea8b1c1bbf91b6df577a561cb.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_184_jpg.rf.d92b146d9a5fe63119679796402fe9bb.jpg from train to /content/filtered_dataset/train
# Copied 530_jpg.rf.7104634a179820395ae2a1afc6b8a72c.jpg from train to /content/filtered_dataset/train
# Copied T111000_jpg.rf.13b963306fbe76e36930aeb6e89de046.jpg from train to /content/filtered_dataset/train
# Copied T112216_jpg.rf.4ab2c6c0c8689f6ec37b01be118550ff.jpg from train to /content/filtered_dataset/train
# Copied Night-Bangladeshi-4K-Walking-Tour-2024-Chittagong-City-4K-Walking-Tour-2024_188_jpg.rf.e44ab30d6fc156f3b421bfcc49ba7645.jpg from train to /content/filtered_dataset/train
# Copied 190_jpg.rf.8a401a57b1a829b83dc71c1b09e6fdc0.jpg from train to /content/filtered_dataset/train
# Copied 1723730713512_jpg.rf.faba03d03118cbc959cad5ac28e3f0ed.jpg from train to /content/filtered_dataset/train
# Copied 120_jpg.rf.ee3851170b8eaa567b23d0eff1075d08.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_594_jpg.rf.637f5c5e3a8e7837df15c9308e713a0b.jpg from train to /content/filtered_dataset/train
# Copied 000318_jpg.rf.b611af0cc462cda3f537926c48862d79.jpg from train to /content/filtered_dataset/train
# Copied images256_jpg.rf.2a9dbe3b99a2a15bf3412b7c4e0887a2.jpg from train to /content/filtered_dataset/train
# Copied 31e6774e3e9d8fa9f740663aa8d5a255_jpg.rf.6f9202e866f1790726cd1839407dce44.jpg from train to /content/filtered_dataset/train
# Copied crossroad-with-side-road-on-the-right22_jpg.rf.e9f749c434d9ea9646a86d3183b29911.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-8-_jpg.rf.fde70afbdbfe7371cc19dff7f9fddb70.jpg from train to /content/filtered_dataset/train
# ...
# Copied T301036_jpg.rf.b8d9d2ec2f85c11b338499cc71ea1f90.jpg from train to /content/filtered_dataset/train
# Copied 000082_jpg.rf.f038cde5c50085cf40fd65c518a34532.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_123_jpg.rf.e7a8f9bec851fc9bc170e93abd7418e2.jpg from train to /content/filtered_dataset/train
# Copied PXL_20231014_072652706_jpg.rf.b5a0da42e48794b508c5e9d2cec57961.jpg from train to /content/filtered_dataset/train
# Copied 159_jpg.rf.94140e4754dd73360d752b1173af306c.jpg from train to /content/filtered_dataset/train
# Copied 3053267399_output_jpg.rf.263b3a6e564eedc522ad87530cd53e08.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-702-_jpg.rf.dc6ca27632174b955d9fbcd8eb618435.jpg from train to /content/filtered_dataset/train
# Copied 108_jpg.rf.93e66ff808445d1996711fc4fda787d2.jpg from train to /content/filtered_dataset/train
# Copied 017_png_jpg.rf.0cafda8d1b98c60035ecdb5c66e41534.jpg from train to /content/filtered_dataset/train
# Copied 39_jpg.rf.e6d8c936ab21a175dd6f70dd6379582e.jpg from train to /content/filtered_dataset/train
# Copied image3_jpeg_jpg.rf.42a5cd00eb6f6ad69c34d797ec1277b2.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-148-_jpg.rf.1e864df2ab1040cc2589724df17804f1.jpg from train to /content/filtered_dataset/train
# Copied T111042_jpg.rf.53b9d9d202965bbbe9285d08673df787.jpg from train to /content/filtered_dataset/train
# Copied images-2-_jpg.rf.3f7a70bfd4055df21a71bac81e421ce6.jpg from train to /content/filtered_dataset/train
# Copied 62ff4c59-Datacluster_Auto_38_jpg.rf.451225f2bb214b436a8fa1aaa2fe1109.jpg from train to /content/filtered_dataset/train
# Copied 000361_jpg.rf.0a1ad4b26a3584a37fadc3e68cf8c3c5.jpg from train to /content/filtered_dataset/train
# Copied 359_jpg.rf.e50d4e0f3da2595aa18ff03977ebe619.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_203_jpg.rf.3561a0e73ef0a11c11199b87f895356f.jpg from train to /content/filtered_dataset/train
# Copied 315_jpg.rf.cc679685e23ee5460e53d8b522e384c2.jpg from train to /content/filtered_dataset/train
# Copied 125_jpg.rf.f599a10fc77d40ba8325a9511fd3ebfb.jpg from train to /content/filtered_dataset/train
# Copied images116_jpg.rf.390d3c36735de6af5817239094a3e81c.jpg from train to /content/filtered_dataset/train
# Copied 021_png_jpg.rf.487c6cc22fd1c2bf447eaf92aa40e2cc.jpg from train to /content/filtered_dataset/train
# Copied 022_png_jpg.rf.1ce62a2cbb23a6c3430efa5872a77912.jpg from train to /content/filtered_dataset/train
# Copied railways1-getty_jpg.rf.d4f3de575d41a507bd6fe11037417e9c.jpg from train to /content/filtered_dataset/train
# Copied crossing34_jpg.rf.e0acfc2b98c0ab43dee80679633c2d48.jpg from train to /content/filtered_dataset/train
# Copied 932_jpg.rf.b045409eb189c80f50cf49c40351275e.jpg from train to /content/filtered_dataset/train
# Copied T112251_jpg.rf.3ecb36a1301cfdc1fc831244c03d16be.jpg from train to /content/filtered_dataset/train
# Copied 2548560039_output_jpg.rf.6a6f82d381c45e2659f7620179105cab.jpg from train to /content/filtered_dataset/train
# Copied IMG_0556_jpg.rf.f4c23d8608ae7115f66168b60e7ac8a9.jpg from train to /content/filtered_dataset/train
# Copied Bengaluru_potholes_ZainabTNM_1200_09062022-compressed_jpg.rf.24915092227cc8b82c1bd32390a253f0.jpg from train to /content/filtered_dataset/train
# Copied 140_png_jpg.rf.5dd4fd1b4347921e40578bb259656bd7.jpg from train to /content/filtered_dataset/train
# Copied T111093_jpg.rf.9e44e2728984ab0695fc169e1145bb0d.jpg from train to /content/filtered_dataset/train
# Copied 129_jpg.rf.a1cf5665f769d9a64e388acfa491021f.jpg from train to /content/filtered_dataset/train
# Copied images180_jpg.rf.6975effb994bb93c4236e952299afe5d.jpg from train to /content/filtered_dataset/train
# Copied 000326_jpg.rf.4acfb47ad070d9ae80afc3e2b3cc8b2a.jpg from train to /content/filtered_dataset/train
# Copied bollard-36-_jpg.rf.60c72f3d5e324c0ae258f48398bb91f9.jpg from train to /content/filtered_dataset/train
# Copied 1723730713373_jpg.rf.56c3db06640b84ee4bc7828b72946592.jpg from train to /content/filtered_dataset/train
# Copied 483_png_jpg.rf.889616871e60ec6e1264406da0ecaac6.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_261_jpg.rf.b6787e600bfa06f608fc6837027d4740.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_17_jpg.rf.c900138a1c0b3969f0462a89968b291a.jpg from train to /content/filtered_dataset/train
# Copied 1247_jpg.rf.6a01430d744936c8dd1198ad3eda4956.jpg from train to /content/filtered_dataset/train
# Copied a2_074_jpg.rf.33ec816bc2286715a60deddc97996478.jpg from train to /content/filtered_dataset/train
# Copied T111129_jpg.rf.4ee6789068151bee9c988a2af6dc2a9e.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-58-_jpg.rf.916f755b8ab9f54592bff50d9110b02a.jpg from train to /content/filtered_dataset/train
# Copied T111100_jpg.rf.90ca893db425c2705f1e646f329d4d4a.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_928_jpg.rf.57d5338ad80c740d7b0e71c494efcacc.jpg from train to /content/filtered_dataset/train
# Copied images104_jpg.rf.ea09b4e8fb15d41c441a73431a9ef6c4.jpg from train to /content/filtered_dataset/train
# Copied a2_068_jpg.rf.2faf79b3119bb890901d61c6e28358b8.jpg from train to /content/filtered_dataset/train
# Copied 485_png_jpg.rf.8bc70f9bfb8e7c6af78fb26fb591ae23.jpg from train to /content/filtered_dataset/train
# Copied VID20240710153612_149_jpg.rf.be519adedbb1610053fe2bf8162cb243.jpg from train to /content/filtered_dataset/train
# Copied 99_jpg.rf.650af12b43280aa01a58aec59abdafea.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-98-_jpg.rf.8d88dbebdd562b2213e5256eb99a6f07.jpg from train to /content/filtered_dataset/train
# Copied crossroad-with-a-side-road-on-the-left4_jpg.rf.0e2ec270a082992bc6baf60bb4771af5.jpg from train to /content/filtered_dataset/train
# Copied a2_298_jpg.rf.47f9d1e9911d03c39bbaee6eb9ba5b06.jpg from train to /content/filtered_dataset/train
# Copied test_mp4-168_jpg.rf.6062a55582f76544502a14a34a2f38f8.jpg from train to /content/filtered_dataset/train
# Copied 102851537-GettyImages-465172040-1_jpg.rf.d55ffee1bda253f271737981f34dc9f8.jpg from train to /content/filtered_dataset/train
# Copied bus-162-_jpg.rf.7583d1f69118d7d14b55d5dd97a01e3a.jpg from train to /content/filtered_dataset/train
# Copied 270_png_jpg.rf.f8eb2b02794a177f6a7343b99f724f56.jpg from train to /content/filtered_dataset/train
# Copied image21_jpeg_jpg.rf.f47f6f7f0f67821a8a12c4077d544b41.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-66-_jpg.rf.9481b48911581d3fa38e51310b5973ec.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-176-_jpg.rf.a3a3ab18e92ae2ff673f58f9dc0c3cfe.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-20-_jpg.rf.930ec7a2848363a7c0b953d0e1b7d13a.jpg from train to /content/filtered_dataset/train
# Copied 028_png_jpg.rf.e4eaf2561873fde48df22eaef0420abe.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_262_jpg.rf.81494455227a3c579f336150acfba0b5.jpg from train to /content/filtered_dataset/train
# Copied 237_jpg.rf.df76c2a0fbf8662e7a71ffae9ed26b6b.jpg from train to /content/filtered_dataset/train
# Copied a2_284_jpg.rf.fdfa4fa8bb9d303b3e9baa5440531ff3.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-211-_jpg.rf.89f172ac47b8cd4db9034a63ee838c89.jpg from train to /content/filtered_dataset/train
# Copied 342_jpg.rf.23331e7d4fce60ff62dea6f5b1b49136.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-65-_jpg.rf.13446cd84010b6439ba1a0d9fd74f226.jpg from train to /content/filtered_dataset/train
# Copied images228_jpg.rf.38485040ce9931305fac5f57a6cb8926.jpg from train to /content/filtered_dataset/train
# Copied 5_jpg.rf.3d1ca70a2df17f72c252fd08d1fbcb0f.jpg from train to /content/filtered_dataset/train
# Copied 141_jpg.rf.ff3bca47d67dc0628cc35c55da090b39.jpg from train to /content/filtered_dataset/train
# Copied curve-to-the-left6_jpg.rf.ca982a7a442019c0f507575852fe9d46.jpg from train to /content/filtered_dataset/train
# Copied 2507355734_output_jpg.rf.1fda543c41875fda95f80bfee40c025b.jpg from train to /content/filtered_dataset/train
# Copied crossroad5_jpg.rf.1d7488f820450b63cfa3b521da31d737.jpg from train to /content/filtered_dataset/train
# Copied 429_jpg.rf.70d3f4a9e0a5341202648086d5e0672d.jpg from train to /content/filtered_dataset/train
# Copied PEDC-55-_png.rf.114b2caefd6ed0855655638e9b43ab66.jpg from train to /content/filtered_dataset/train
# Copied 106_jpg.rf.6d683bb2d6a0ce260a99601ed1a2c906.jpg from train to /content/filtered_dataset/train
# Copied images26_jpg.rf.e728aec2673c32f76444ab0d080de96d.jpg from train to /content/filtered_dataset/train
# Copied 1309_jpg.rf.84cbebdc170616e522a2e71ecaef9164.jpg from train to /content/filtered_dataset/train
# Copied 300px-Newport_Whitepit_Lane_pot_hole-JPG_jpg.rf.903e355e9a312d96dbb475e1a44f6f57.jpg from train to /content/filtered_dataset/train
# Copied 96_jpg.rf.07959b35dc6d7c3e4cd826a03182a9e1.jpg from train to /content/filtered_dataset/train
# Copied T111036_jpg.rf.1240f2b82d455872f2b30099e351a59e.jpg from train to /content/filtered_dataset/train
# Copied images-26_jpeg.rf.ef5ffed690afe88e665d4c32c4143750.jpg from train to /content/filtered_dataset/train
# Copied close-up-big-pothole-with-dirty-rain-water-road_127089-5185_jpg.rf.e88afadb73f62a45d2d28f7b705c9c96.jpg from train to /content/filtered_dataset/train
# Copied file-20180824-149463-1hzm435_jpg.rf.6d0f235acf3bc585942ac3a45a87b56f.jpg from train to /content/filtered_dataset/train
# Copied bollard-17-_jpg.rf.1c9c0c5f29ca05e283b432751ba3d66f.jpg from train to /content/filtered_dataset/train
# Copied 252_jpg.rf.c40de573b4e5682151c113541faba555.jpg from train to /content/filtered_dataset/train
# Copied 016_png_jpg.rf.a391f484aaf0ab4c448031942620e48a.jpg from train to /content/filtered_dataset/train
# Copied IMG-20210903-WA0017_output_output_jpg.rf.53deb162bfe8a2094ba1293055454529.jpg from train to /content/filtered_dataset/train
# Copied 1723730712232_jpg.rf.67a7b2a7d045a3a9360e79d3a0e7f38f.jpg from train to /content/filtered_dataset/train
# Copied 1723730713074_jpg.rf.4844a7bb4649ceac52e3bc027d198438.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_48_jpg.rf.b2e88114e0ad8709bb838a6e27ab1b4b.jpg from train to /content/filtered_dataset/train
# Copied 003_png_jpg.rf.bdd3fe8af5e1955260e740781aff31b2.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-66-_jpg.rf.1bcc3b9b1915f50cf4f786a09e538ce1.jpg from train to /content/filtered_dataset/train
# Copied 175_jpg.rf.831574e9a24561710121f044bcaef553.jpg from train to /content/filtered_dataset/train
# Copied 000076_jpg.rf.e2363d91e9389864c4c4b17788c0e473.jpg from train to /content/filtered_dataset/train
# Copied 1-8-_jpg.rf.8f0edac9f7be6747b754a0e6c1b55cc0.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-63-_jpg.rf.9b44f94f932d1c5f3c580474fd5515b7.jpg from train to /content/filtered_dataset/train
# Copied 0002393_jpg.rf.86b2c16b9ce2fe932de8c1a462857ca7.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_219_jpg.rf.33f7890661ef50691e85d761d1ceb88a.jpg from train to /content/filtered_dataset/train
# Copied 000050_jpg.rf.c201fa407b0152093c0c9a88a225c74e.jpg from train to /content/filtered_dataset/train
# Copied bBGk8L_YEk0_jpg.rf.2eb3bd4744020351926c06891764f9e8.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_25_jpg.rf.bfaf27ce1a49b8a9c2f3b60421373605.jpg from train to /content/filtered_dataset/train
# Copied T111148_jpg.rf.c71112d59c04bb42bdc8284a5e9f7974.jpg from train to /content/filtered_dataset/train
# Copied IMG_0538_jpg.rf.ac15c9fad36548592a9981d020a2a2f5.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-73-_jpg.rf.dee8fb3167ff6469c00b71d52996a5c4.jpg from train to /content/filtered_dataset/train
# Copied image31_jpeg_jpg.rf.3ce02fafb293b7e4ab5dd2cc8ade7d41.jpg from train to /content/filtered_dataset/train
# Copied VID20240710154006_22_jpg.rf.8e748e55338983bf3323b65b8a729cf5.jpg from train to /content/filtered_dataset/train
# Copied 126_jpg.rf.939e373659af03a607b776f3a624da3b.jpg from train to /content/filtered_dataset/train
# Copied 353_jpg.rf.812c265cb04e4c0aa7c278bf8737f5a8.jpg from train to /content/filtered_dataset/train
# Copied PXL_20231014_074146003_jpg.rf.e47987cf290ccf1bdb8e78c0bd036417.jpg from train to /content/filtered_dataset/train
# Copied traffic-light-211-_jpg.rf.271e4a7b484c61fd18bf27e86e4b6d6f.jpg from train to /content/filtered_dataset/train
# Copied 4K-Bangladeshi-walking-tour-Dhaka-city-2023-Bason-Thana-Gazipur-Walking-Tour-2023_105_jpg.rf.5a572cbf1809d65b816bb34bee583f06.jpg from train to /content/filtered_dataset/train
# Copied STOP-7-_jpg.rf.cec79d8d91d66a96e99248bed881f2e5.jpg from train to /content/filtered_dataset/train
# Copied crossroad-with-side-road-on-the-right29_jpg.rf.f63d235d3737f09bfb356d83d788e7c4.jpg from train to /content/filtered_dataset/train
# Copied IMG_0555_jpg.rf.ebd0c790ec49a6e08d5afdb385e632dc.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_137_jpg.rf.72f226116282c2641f3dd9a989c705c8.jpg from train to /content/filtered_dataset/train
# Copied 1084_jpg.rf.2095d0e72ac0d6f78203f4552a0f3d94.jpg from train to /content/filtered_dataset/train
# Copied 114_png_jpg.rf.c0a9279aab3cb7c9fe8225dc033241a1.jpg from train to /content/filtered_dataset/train
# Copied images104_jpg.rf.b1ea51a9c9fd81b54413fa665b730573.jpg from train to /content/filtered_dataset/train
# Copied T111184_jpg.rf.290097c2f8e22721f39c2570c27718a7.jpg from train to /content/filtered_dataset/train
# Copied 218_png_jpg.rf.aeb8954346535aaa84dc77d778c0cff2.jpg from train to /content/filtered_dataset/train
# Copied 000028_jpg.rf.57c6a6af1abebe6ce7594c62525e7b4c.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-18-_jpg.rf.4e1dd45d856c9b68ce9550605950ce54.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-45-_jpg.rf.26d22178d8253391705ade19bfdb4bd5.jpg from train to /content/filtered_dataset/train
# Copied 88_jpg.rf.2e84549f75165a24b87b670fd42688cf.jpg from train to /content/filtered_dataset/train
# Copied bus-138-_jpg.rf.f18e09609eee3ae1950c6e55e8d77769.jpg from train to /content/filtered_dataset/train
# Copied 268_jpg.rf.6181a836d1f159f3d86ec008e5567bd3.jpg from train to /content/filtered_dataset/train
# Copied 413_jpg.rf.95485049a12f2139bce0737b316c63c2.jpg from train to /content/filtered_dataset/train
# Copied 206_jpg.rf.e8dd5ad45a68304b17d6140a9497443f.jpg from train to /content/filtered_dataset/train
# Copied VID20240714180347_79_jpg.rf.ba5401c65a70eeec5845c31c847281ba.jpg from train to /content/filtered_dataset/train
# Copied standing_8_11_23-67-_jpg.rf.1b739d252e9b88254183bceb0f29f05e.jpg from train to /content/filtered_dataset/train
# Copied 451_jpg.rf.882eb370e97c816c01ece98baf00a56e.jpg from train to /content/filtered_dataset/train
# Copied 2023-Bangladeshi-Rail-crossing-syestem-Bangladesh-railway-High-speed-train-in-Bangladesh_20_jpg.rf.796d7684c1f479b1b9676a03d329dd2f.jpg from train to /content/filtered_dataset/train
# Copied 1723730713380_jpg.rf.2800367b93c8398a20bc0a33e606429f.jpg from train to /content/filtered_dataset/train
# Copied Night-Bangladeshi-4K-Walking-Tour-2024-Chittagong-City-4K-Walking-Tour-2024_136_jpg.rf.2f1656abbd4987f2e707abd578464456.jpg from train to /content/filtered_dataset/train
# Copied images252_jpg.rf.a8f02f33530e13b33103d6a92a7bc7b1.jpg from train to /content/filtered_dataset/train
# Copied SAHED-18-_png.rf.88160674402b9902185aefaf1c770119.jpg from train to /content/filtered_dataset/train
# Copied 017_png_jpg.rf.d41cdd7446fa9218d44238b3fa24e54e.jpg from train to /content/filtered_dataset/train

# %%
import json

# Load annotation JSON file
with open(f"{dataset_dir}/train/_annotations.coco.json", "r") as f:
    data = json.load(f)

# Print top-level keys
print(data.keys())

# Extract category names
category_names = [category["name"] for category in data["categories"] if category["name"] != 'car-vehicle-dog-animal-curb-wall']

# Print the list of category names
print(category_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5a6b578ade0f> in <cell line: 0>()
#       2
#       3 # Load annotation JSON file
# ----> 4 with open(f"{dataset_dir}/train/_annotations.coco.json", "r") as f:
#       5     data = json.load(f)
#       6
#
# NameError: name 'dataset_dir' is not defined

# %%
import fiftyone.brain as fob
import fiftyone.zoo as foz

# %%
model = foz.load_zoo_model(
    "zero-shot-detection-transformer-torch",
    name_or_path="google/owlvit-base-patch32",
    classes=category_names,
)
